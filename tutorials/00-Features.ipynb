# %% [markdown]
# # How AI sees malware - Part 1
#
# In this demo, you will learn how samples are broken down into some numbers that AI models can crunch to inference maliciousness.
#
# This can be achieved in two ways:
# * extracting metrics, known as "features" that tentatively describe samples in a more abstract way
# * feeding giant neural networks with raw data
