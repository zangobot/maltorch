# %% [markdown]
# # Loading models and computing inference
# Within `maltorch` it is possible to laod pre-trained models and compute inference right away.

# %%
# %%capture --no-stderr
try:
    import maltorch
except ImportError:
   # %pip install git+https://github.com/zangobot/maltorch
